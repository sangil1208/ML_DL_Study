# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
cd /content/drive/MyDrive/ML_DL_STUDY/Github/ML_DL_Study
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ML_DL_STUDY/Github/ML_DL_Study'
# /content
